# %%
import numpy as np
from csc.utils import *
from csc.atoms import *
from csc.dictionary import *
from csc.workbench import *
from itertools import product
import matplotlib.pyplot as plt

# Atom parameters
bmin = 0.005
bmax = 0.06
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.010
ymax = 0.036
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 143 different atoms

# %%
batchSize = 200

max_sparsity = 30

input_mmpdf_db = f'/home/gomes/synthetic-data/csc-mmpdf-{batchSize}.json'
output_prc_omp_db = f'/home/gomes/synthetic-data/prc-omp-{batchSize}.json'

path_to_signals_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\csc-signals-{batchSize}.json'
#path_to_signals_db = f'/home/gomes/synthetic-data/csc-signals-{batchSize}.json'

path_to_prc_mmpdf_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mmpdf20-{batchSize}.json'
path_to_prc_mmpdf27_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mmpdf27-{batchSize}.json'
path_to_prc_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-omp-{batchSize}.json'
path_to_prc_mp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mp-{batchSize}.json'

workbench = CSCWorkbench(path_to_signals_db)
workbench.load_data()
workbench.set_dictionary(dictionary)

# %%
workbench.plotPRCurvesFromDB(
    MMP=path_to_prc_mmpdf_db,
    OMP=path_to_prc_omp_db,
    MP=path_to_prc_mp_db,
    n_samples=100,
    max_sparsity=30
    )

# %%
workbench.plotPRCurvesFromDB(
    MMP=path_to_prc_mmpdf27_db,
    OMP=path_to_prc_omp_db,
    MP=path_to_prc_mp_db,
    n_samples=100,
    max_sparsity=30
    )

# %% [markdown]
# ## Remarques
# 1. Comment jouer sur les métroques d'appariemment pour montrer la supériorité de la MMP-DF par rapport à l'OMP.
# 2. Comment penser la pipeline PRC en conséquence pour pouvoir jouer __a posteriori__ sur les paramètres d'appariements ?

# %%
workbench.plotPRCurvesFromDB(
    MMP=path_to_prc_mmpdf_db,
    OMP=path_to_prc_omp_db,
    MP=path_to_prc_mp_db,
    n_samples=100,
    max_sparsity=10
    )

# %%
workbench.plotPRCurvesFromDB(
    MMP=path_to_prc_mmpdf27_db,
    OMP=path_to_prc_omp_db,
    MP=path_to_prc_mp_db,
    n_samples=100,
    max_sparsity=10
    )

# %%
workbench.plotPRCSNRFromDB(
    MMPDF=path_to_prc_mmpdf27_db,
    n_samples=100,
    max_sparsity=30
    )
