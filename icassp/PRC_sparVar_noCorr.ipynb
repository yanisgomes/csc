# %%
import numpy as np
from csc.utils import *
from csc.atoms import *
from csc.dictionary import *
from csc.workbench import *
from itertools import product
import matplotlib.pyplot as plt

# Atom parameters
bmin = 0.005
bmax = 0.06
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.010
ymax = 0.036
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 143 different atoms

# %%
batchSize = 200
max_sparsity = 30

pomme = False

if pomme :
    input_mmpdf_db = f'/home/gomes/synthetic-data/csc-mmpdf-{batchSize}.json'
    output_prc_omp_db = f'/home/gomes/synthetic-data/prc-omp-{batchSize}.json'
    
    # Signal DB
    path_to_signals_db = path_to_signals_db = f'/home/gomes/synthetic-data/csc-signals-{batchSize}.json'
    
    # Precison-Recall Curves DB
    path_to_prc_mmpdf27_db = f'/home/gomes/synthetic-data/prc-mmpdf27-{batchSize}.json'
    path_to_prc_mmpdf20_db = f'/home/gomes/synthetic-data/prc-mmpdf20-{batchSize}.json'
    path_to_prc_omp_db = f'/home/gomes/synthetic-data/prc-omp-{batchSize}.json'
    path_to_prc_mp_db = f'/home/gomes/synthetic-data/prc-mp-{batchSize}.json'

    # Sparsity Variations DB
    path_sparVar_mmpdf9_db = f'/home/gomes/synthetic-data/sparVar-mmpdf9-{batchSize}.json'
    path_sparVar_omp_db = f'/home/gomes/synthetic-data/sparVar-omp-{batchSize}.json'
    path_sparVar_mp_db = f'/home/gomes/synthetic-data/sparVar-mp-{batchSize}.json'
    path_sparVar_alphaCSC_db = f'/home/gomes/synthetic-data/sparVar-alphaCSC-{batchSize}.json'

else:
    # Signal DB
    path_to_signals_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\csc-signals-{batchSize}.json'
    
    # Precison-Recall Curves DB
    path_to_prc_mmpdf27_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mmpdf27-{batchSize}.json'
    path_to_prc_mmpdf20_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mmpdf20-{batchSize}.json'
    path_to_prc_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-omp-{batchSize}.json'
    path_to_prc_mp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\prc-mp-{batchSize}.json'
    
    # Sparsity Variations DB
    path_sparVar_mmpdf27_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\sparVar-mmpdf27-{batchSize}.json'
    path_sparVar_mmpdf9_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\sparVar-mmpdf9-{batchSize}.json'
    path_sparVar_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\sparVar-omp-{batchSize}.json'
    path_sparVar_mp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\sparVar-mp-{batchSize}.json'
    path_sparVar_L1_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\sparVar-L1-{batchSize}.json'

workbench = CSCWorkbench(path_to_signals_db)
workbench.load_data()
workbench.set_dictionary(dictionary)

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 10,
    sparsity = 4,
    max_sparsity=7,
    position_error_threshold=5,
    verbose=True
    )
# Out:
# SNR = 10
# Sparsity = 4
# Max sparsity = 7
# Position error threshold = 5
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 200 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 200 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 200 arrays of PR metrics
# ...

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 10,
    sparsity = 7,
    max_sparsity=7,
    position_error_threshold=10,
    verbose=True
    )
# Out:
# SNR = 10
# Sparsity = 7
# Max sparsity = 7
# Position error threshold = 10
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 200 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 200 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 200 arrays of PR metrics
# ...

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 15,
    sparsity = 7,
    max_sparsity=7,
    position_error_threshold=3,
    verbose=True
    )
# Out:
# SNR = 15
# Sparsity = 7
# Max sparsity = 7
# Position error threshold = 3
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 200 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 200 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 200 arrays of PR metrics
# ...

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 10,
    sparsity = 6,
    max_sparsity=6,
    position_error_threshold=3,
    verbose=True
    )
# Out:
# SNR = 10
# Sparsity = 6
# Max sparsity = 6
# Position error threshold = 3
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 200 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 200 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 200 arrays of PR metrics
# ...

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 10,
    sparsity = 5,
    max_sparsity=5,
    position_error_threshold=1,
    verbose=True
    )
# Out:
# SNR = 10
# Sparsity = 5
# Max sparsity = 5
# Position error threshold = 1
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 200 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 200 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 200 arrays of PR metrics
# ...

# %%
workbench.plotPRCFromSparVarDB(
    #CSC_L1=path_sparVar_L1_db,
    CSC_MMP27=path_sparVar_mmpdf27_db,
    CSC_MMP9=path_sparVar_mmpdf9_db,
    CSC_OMP=path_sparVar_omp_db,
    CSC_MP=path_sparVar_mp_db,
    snr = 5,
    sparsity = -1,
    max_sparsity=7,
    position_error_threshold=30,
    verbose=True
    )
# Out:
# SNR = 5
# Sparsity = -1
# Max sparsity = 7
# Position error threshold = 30
# CSC_MMP27 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf27-200.json : 1000 arrays of PR metrics
# CSC_MMP9 : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-mmpdf9-200.json : 1000 arrays of PR metrics
# CSC_OMP : compute PRC from C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json
#     -> C:\Users\gomes\Documents\ENS\00_M1\00_BORELLI\01_WorkInProgress\\synthetic-data\sparVar-omp-200.json : 1000 arrays of PR metrics
# ...
