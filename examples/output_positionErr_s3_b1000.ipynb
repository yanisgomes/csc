# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %% [markdown]
# ### Erreur en position ``sparsity_level = 3`` & ``batch_size = 1000``

# %%
import numpy as np
import pandas as pd
from numba import njit
from csc.atoms import *
from csc.dictionary import *
import matplotlib.pyplot as plt

# atom parameters
bmin = 0.005
bmax = 0.60
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.01
ymax = 0.034
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 1428 different atoms

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
positionErrors3_100 = dictionary.ompPositionErrorPipeline(sparsity_level=3, batch_size=1000, cores=50, verbose=False)
# Out:
# OMP Test Batch for noise_level = 0.00:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.01:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.02:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.03:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.04:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.05:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.07:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.06:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.08:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.09:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.10:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.14:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.16:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.18:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.20:   0%|          | 0/1000 [00:00<?, ?it/s]
# OMP Test Batch for noise_level = 0.01:   0%|          | 1/1000 [00:31<8:42:38, 31.39s/it]
# OMP Test Batch for noise_level = 0.05:   0%|          | 1/1000 [00:33<9:12:04, 33.16s/it]
# OMP Test Batch for noise_level = 0.00:   0%|          | 1/1000 [00:41<11:24:01, 41.08s/it]
# OMP Test Batch for noise_level = 0.20:   0%|          | 1/1000 [00:32<8:53:15, 32.03s/it]
# OMP Test Batch for noise_level = 0.08:   0%|          | 1/1000 [00:38<10:33:02, 38.02s/it]
# OMP Test Batch for noise_level = 0.04:   0%|          | 1/1000 [00:43<11:57:15, 43.08s/it]
# OMP Test Batch for noise_level = 0.03:   0%|          | 1/1000 [00:45<12:32:10, 45.18s/it]
# OMP Test Batch for noise_level = 0.02:   0%|          | 1/1000 [00:46<12:55:07, 46.55s/it]
# OMP Test Batch for noise_level = 0.12:   0%|          | 1/1000 [00:40<11:08:12, 40.13s/it]
# OMP Test Batch for noise_level = 0.07:   0%|          | 1/1000 [00:45<12:45:06, 45.95s/it]
# OMP Test Batch for noise_level = 0.06:   0%|          | 1/1000 [00:48<13:34:55, 48.94s/it]
# OMP Test Batch for noise_level = 0.18:   0%|          | 1/1000 [00:44<12:13:42, 44.07s/it]
# OMP Test Batch for noise_level = 0.09:   0%|          | 1/1000 [00:54<15:00:58, 54.11s/it]
# OMP Test Batch for noise_level = 0.01:   0%|          | 2/1000 [01:07<9:33:11, 34.46s/it]
# OMP Test Batch for noise_level = 0.00:   0%|          | 2/1000 [01:17<10:36:20, 38.26s/it]
# OMP Test Batch for noise_level = 0.16:   0%|          | 2/1000 [01:10<9:46:55, 35.29s/it]
# OMP Test Batch for noise_level = 0.20:   0%|          | 2/1000 [01:08<9:34:56, 34.57s/it]
# OMP Test Batch for noise_level = 0.08:   0%|          | 2/1000 [01:14<10:20:10, 37.28s/it]
# OMP Test Batch for noise_level = 0.14:   0%|          | 2/1000 [01:12<10:08:17, 36.57s/it]
# OMP Test Batch for noise_level = 0.04:   0%|          | 2/1000 [01:19<10:53:38, 39.30s/it]
# OMP Test Batch for noise_level = 0.05:   0%|          | 2/1000 [01:23<11:57:02, 43.11s/it]
# OMP Test Batch for noise_level = 0.06:   0%|          | 2/1000 [01:26<11:42:26, 42.23s/it]
# OMP Test Batch for noise_level = 0.12:   0%|          | 2/1000 [01:33<13:13:42, 47.72s/it]
# OMP Test Batch for noise_level = 0.02:   0%|          | 2/1000 [01:43<14:33:36, 52.52s/it]
# OMP Test Batch for noise_level = 0.07:   0%|          | 2/1000 [01:40<14:11:44, 51.21s/it]
# OMP Test Batch for noise_level = 0.01:   0%|          | 3/1000 [01:46<10:06:02, 36.47s/it]
# OMP Test Batch for noise_level = 0.10:   0%|          | 2/1000 [01:43<14:12:19, 51.24s/it]
# OMP Test Batch for noise_level = 0.00:   0%|          | 3/1000 [01:52<10:14:02, 36.95s/it]
# OMP Test Batch for noise_level = 0.16:   0%|          | 3/1000 [01:46<9:47:59, 35.39s/it]
# OMP Test Batch for noise_level = 0.08:   0%|          | 3/1000 [01:50<10:07:25, 36.56s/it]
# OMP Test Batch for noise_level = 0.20:   0%|          | 3/1000 [01:46<10:04:38, 36.39s/it]
# OMP Test Batch for noise_level = 0.04:   0%|          | 3/1000 [01:56<10:34:14, 38.17s/it]
# OMP Test Batch for noise_level = 0.05:   0%|          | 3/1000 [02:00<11:08:59, 40.26s/it]
# OMP Test Batch for noise_level = 0.18:   0%|          | 3/1000 [01:55<10:20:07, 37.32s/it]
# OMP Test Batch for noise_level = 0.06:   0%|          | 3/1000 [02:03<11:00:47, 39.77s/it]
# OMP Test Batch for noise_level = 0.03:   0%|          | 3/1000 [02:16<12:50:05, 46.34s/it]
# OMP Test Batch for noise_level = 0.14:   0%|          | 3/1000 [02:10<12:46:03, 46.10s/it]
# OMP Test Batch for noise_level = 0.00:   0%|          | 4/1000 [02:22<9:24:59, 34.04s/it]
# OMP Test Batch for noise_level = 0.20:   0%|          | 4/1000 [02:18<9:34:12, 34.59s/it]
# OMP Test Batch for noise_level = 0.08:   0%|          | 4/1000 [02:24<9:49:13, 35.50s/it]
# OMP Test Batch for noise_level = 0.18:   0%|          | 4/1000 [02:24<9:23:46, 33.96s/it]
# OMP Test Batch for noise_level = 0.07:   0%|          | 3/1000 [02:30<14:02:29, 50.70s/it]
# OMP Test Batch for noise_level = 0.04:   0%|          | 4/1000 [02:32<10:22:12, 37.48s/it]
# OMP Test Batch for noise_level = 0.01:   0%|          | 4/1000 [02:38<11:41:55, 42.28s/it]
# OMP Test Batch for noise_level = 0.02:   0%|          | 3/1000 [02:39<14:59:45, 54.15s/it]
# OMP Test Batch for noise_level = 0.10:   0%|          | 3/1000 [02:35<14:21:03, 51.82s/it]
# OMP Test Batch for noise_level = 0.06:   0%|          | 4/1000 [02:38<10:32:12, 38.08s/it]
# OMP Test Batch for noise_level = 0.05:   0%|          | 4/1000 [02:44<11:35:22, 41.89s/it]
# OMP Test Batch for noise_level = 0.14:   0%|          | 4/1000 [02:40<11:00:58, 39.82s/it]
# OMP Test Batch for noise_level = 0.03:   0%|          | 4/1000 [02:48<11:13:20, 40.56s/it]
# OMP Test Batch for noise_level = 0.00:   0%|          | 5/1000 [02:54<9:15:16, 33.48s/it]
# OMP Test Batch for noise_level = 0.09:   0%|          | 3/1000 [02:47<15:31:26, 56.05s/it]
# OMP Test Batch for noise_level = 0.16:   0%|          | 5/1000 [02:51<9:16:10, 33.54s/it]
# OMP Test Batch for noise_level = 0.20:   0%|          | 5/1000 [02:53<9:35:10, 34.68s/it]
# OMP Test Batch for noise_level = 0.18:   0%|          | 5/1000 [02:55<9:08:07, 33.05s/it]
# OMP Test Batch for noise_level = 0.04:   0%|          | 5/1000 [03:06<9:59:23, 36.14s/it]
# OMP Test Batch for noise_level = 0.08:   0%|          | 5/1000 [03:04<10:15:58, 37.14s/it]
# OMP Test Batch for noise_level = 0.07:   0%|          | 4/1000 [03:09<12:38:56, 45.72s/it]
# OMP Test Batch for noise_level = 0.01:   0%|          | 5/1000 [03:13<11:01:24, 39.88s/it]
# OMP Test Batch for noise_level = 0.03:   0%|          | 5/1000 [03:19<10:16:05, 37.15s/it]
# OMP Test Batch for noise_level = 0.14:   0%|          | 5/1000 [03:15<10:30:53, 38.04s/it]
# OMP Test Batch for noise_level = 0.10:   0%|          | 4/1000 [03:18<13:21:13, 48.27s/it]
# OMP Test Batch for noise_level = 0.06:   0%|          | 5/1000 [03:21<10:59:12, 39.75s/it]
# OMP Test Batch for noise_level = 0.12:   0%|          | 4/1000 [03:19<14:10:59, 51.26s/it]
# OMP Test Batch for noise_level = 0.00:   1%|          | 6/1000 [03:30<9:28:57, 34.34s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 6/1000 [03:23<9:06:56, 33.01s/it]
# OMP Test Batch for noise_level = 0.02:   0%|          | 4/1000 [03:36<15:21:33, 55.52s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 6/1000 [03:28<9:36:55, 34.82s/it]
# OMP Test Batch for noise_level = 0.09:   0%|          | 4/1000 [03:33<14:21:01, 51.87s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 6/1000 [03:32<9:26:24, 34.19s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 6/1000 [03:41<9:49:12, 35.57s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 6/1000 [03:38<10:00:00, 36.22s/it]
# OMP Test Batch for noise_level = 0.05:   0%|          | 5/1000 [03:43<13:15:55, 48.00s/it]
# OMP Test Batch for noise_level = 0.07:   0%|          | 5/1000 [03:45<11:40:06, 42.22s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 6/1000 [03:52<9:52:51, 35.79s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 6/1000 [03:47<9:55:38, 35.95s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 6/1000 [03:56<11:18:46, 40.97s/it]
# OMP Test Batch for noise_level = 0.10:   0%|          | 5/1000 [03:54<12:06:35, 43.81s/it]
# OMP Test Batch for noise_level = 0.00:   1%|          | 7/1000 [04:06<9:37:45, 34.91s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 7/1000 [04:00<9:29:51, 34.43s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 6/1000 [04:06<11:29:33, 41.62s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 7/1000 [04:08<9:22:43, 34.00s/it]
# OMP Test Batch for noise_level = 0.12:   0%|          | 5/1000 [04:08<13:55:20, 50.37s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 7/1000 [04:06<9:50:04, 35.65s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 7/1000 [04:09<9:44:57, 35.34s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 6/1000 [04:20<11:03:33, 40.05s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 7/1000 [04:19<9:36:34, 34.84s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 7/1000 [04:30<11:02:55, 40.06s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 7/1000 [04:34<10:58:10, 39.77s/it]
# OMP Test Batch for noise_level = 0.02:   0%|          | 5/1000 [04:35<15:37:02, 56.51s/it]
# OMP Test Batch for noise_level = 0.09:   0%|          | 5/1000 [04:31<14:56:15, 54.05s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 6/1000 [04:31<11:29:09, 41.60s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 6/1000 [04:36<13:45:39, 49.84s/it]
# OMP Test Batch for noise_level = 0.00:   1%|          | 8/1000 [04:42<9:38:20, 34.98s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 8/1000 [04:38<9:01:44, 32.77s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 8/1000 [04:39<9:53:25, 35.89s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 8/1000 [04:40<9:40:28, 35.11s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 7/1000 [04:48<11:29:00, 41.63s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 8/1000 [04:43<9:38:34, 34.99s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 8/1000 [04:54<9:09:56, 33.26s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 7/1000 [04:55<10:31:44, 38.17s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 8/1000 [04:55<9:40:15, 35.10s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 6/1000 [05:01<14:10:57, 51.37s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 7/1000 [05:07<10:55:32, 39.61s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 9/1000 [05:09<8:54:16, 32.35s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 9/1000 [05:08<9:16:55, 33.72s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 8/1000 [05:21<11:57:27, 43.39s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 9/1000 [05:23<8:48:34, 32.00s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 8/1000 [05:26<12:05:15, 43.87s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 9/1000 [05:16<9:49:30, 35.69s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 8/1000 [05:27<10:02:47, 36.46s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 6/1000 [05:32<15:38:27, 56.65s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 6/1000 [05:27<15:09:38, 54.91s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 7/1000 [05:34<14:26:48, 52.37s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 8/1000 [05:40<10:22:39, 37.66s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 10/1000 [05:44<9:03:15, 32.92s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 9/1000 [05:42<10:42:33, 38.90s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 10/1000 [05:42<9:17:34, 33.79s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 10/1000 [05:57<8:55:03, 32.43s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 10/1000 [05:50<9:22:46, 34.11s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 10/1000 [05:52<9:47:40, 35.62s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 9/1000 [05:59<10:36:51, 38.56s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 9/1000 [06:02<9:49:52, 35.71s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 9/1000 [06:07<11:50:54, 43.04s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 7/1000 [06:00<14:53:11, 53.97s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 9/1000 [06:14<12:50:54, 46.67s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 11/1000 [06:12<8:56:39, 32.56s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 9/1000 [06:14<10:01:30, 36.42s/it]
# OMP Test Batch for noise_level = 0.00:   1%|          | 11/1000 [06:22<9:18:09, 33.86s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 11/1000 [06:17<9:03:31, 32.97s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 10/1000 [06:18<10:23:38, 37.80s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 11/1000 [06:19<8:56:34, 32.55s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 8/1000 [06:26<14:26:55, 52.44s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 11/1000 [06:29<8:53:06, 32.34s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 7/1000 [06:31<15:50:11, 57.41s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 7/1000 [06:26<15:31:45, 56.30s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 11/1000 [06:23<9:25:29, 34.31s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 10/1000 [06:36<9:44:32, 35.43s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 10/1000 [06:39<10:41:06, 38.86s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 10/1000 [06:48<11:36:49, 42.23s/it]
# OMP Test Batch for noise_level = 0.16:   1%|          | 12/1000 [06:46<9:01:00, 32.85s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 10/1000 [06:47<9:45:28, 35.48s/it]
# OMP Test Batch for noise_level = 0.00:   1%|          | 12/1000 [06:56<9:20:18, 34.03s/it]
# OMP Test Batch for noise_level = 0.08:   1%|          | 12/1000 [06:53<9:19:37, 33.99s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 11/1000 [06:51<10:01:26, 36.49s/it]
# OMP Test Batch for noise_level = 0.18:   1%|          | 12/1000 [06:54<9:10:53, 33.45s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 8/1000 [06:59<15:16:55, 55.46s/it]
# OMP Test Batch for noise_level = 0.20:   1%|          | 12/1000 [06:59<9:29:34, 34.59s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 10/1000 [07:07<13:21:28, 48.57s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 11/1000 [07:10<9:37:26, 35.03s/it]
# OMP Test Batch for noise_level = 0.03:   1%|          | 12/1000 [07:16<10:06:42, 36.84s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 11/1000 [07:20<10:50:19, 39.45s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 11/1000 [07:17<9:17:14, 33.81s/it]
# OMP Test Batch for noise_level = 0.16:   1%|▏         | 13/1000 [07:19<9:03:31, 33.04s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 9/1000 [07:25<14:57:21, 54.33s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 11/1000 [07:28<11:25:59, 41.62s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 8/1000 [07:29<15:52:30, 57.61s/it]
# OMP Test Batch for noise_level = 0.00:   1%|▏         | 13/1000 [07:31<9:23:18, 34.24s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 8/1000 [07:24<15:38:24, 56.76s/it]
# OMP Test Batch for noise_level = 0.08:   1%|▏         | 13/1000 [07:27<9:19:34, 34.02s/it]
# OMP Test Batch for noise_level = 0.14:   1%|          | 12/1000 [07:25<9:48:13, 35.72s/it]
# OMP Test Batch for noise_level = 0.18:   1%|▏         | 13/1000 [07:29<9:17:24, 33.89s/it]
# OMP Test Batch for noise_level = 0.20:   1%|▏         | 13/1000 [07:31<9:18:28, 33.95s/it]
# OMP Test Batch for noise_level = 0.10:   1%|          | 12/1000 [07:49<9:06:10, 33.17s/it]
# OMP Test Batch for noise_level = 0.07:   1%|          | 12/1000 [07:53<10:14:32, 37.32s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 9/1000 [07:52<15:03:16, 54.69s/it]
# OMP Test Batch for noise_level = 0.00:   1%|▏         | 14/1000 [08:01<9:00:30, 32.89s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 11/1000 [07:58<13:32:30, 49.29s/it]
# OMP Test Batch for noise_level = 0.14:   1%|▏         | 13/1000 [07:55<9:18:28, 33.95s/it]
# OMP Test Batch for noise_level = 0.03:   1%|▏         | 13/1000 [08:03<10:56:48, 39.93s/it]
# OMP Test Batch for noise_level = 0.08:   1%|▏         | 14/1000 [08:01<9:17:47, 33.94s/it]
# OMP Test Batch for noise_level = 0.06:   1%|          | 12/1000 [08:06<11:24:52, 41.59s/it]
# OMP Test Batch for noise_level = 0.18:   1%|▏         | 14/1000 [08:02<9:14:17, 33.73s/it]
# OMP Test Batch for noise_level = 0.01:   1%|          | 12/1000 [08:12<11:38:39, 42.43s/it]
# OMP Test Batch for noise_level = 0.20:   1%|▏         | 14/1000 [08:06<9:22:08, 34.21s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 10/1000 [08:22<15:09:45, 55.14s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 9/1000 [08:25<15:44:42, 57.20s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 9/1000 [08:21<15:39:22, 56.87s/it]
# OMP Test Batch for noise_level = 0.10:   1%|▏         | 13/1000 [08:21<9:00:10, 32.84s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 15/1000 [08:25<9:00:20, 32.91s/it]
# OMP Test Batch for noise_level = 0.14:   1%|▏         | 14/1000 [08:29<9:19:54, 34.07s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 15/1000 [08:38<9:22:51, 34.29s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 15/1000 [08:34<9:13:04, 33.69s/it]
# OMP Test Batch for noise_level = 0.03:   1%|▏         | 14/1000 [08:40<10:44:01, 39.19s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 15/1000 [08:34<9:02:26, 33.04s/it]
# OMP Test Batch for noise_level = 0.07:   1%|▏         | 13/1000 [08:43<11:18:54, 41.27s/it]
# OMP Test Batch for noise_level = 0.01:   1%|▏         | 13/1000 [08:48<11:04:40, 40.41s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 15/1000 [08:39<9:16:26, 33.89s/it]
# OMP Test Batch for noise_level = 0.04:   1%|          | 12/1000 [08:50<13:46:03, 50.17s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 10/1000 [08:49<15:15:18, 55.47s/it]
# OMP Test Batch for noise_level = 0.10:   1%|▏         | 14/1000 [08:53<8:56:36, 32.65s/it]
# OMP Test Batch for noise_level = 0.06:   1%|▏         | 13/1000 [08:59<12:21:26, 45.07s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 16/1000 [08:58<9:03:14, 33.12s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 15/1000 [09:04<9:24:33, 34.39s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 16/1000 [09:09<9:20:08, 34.16s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 15/1000 [09:14<10:17:07, 37.59s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 16/1000 [09:08<9:08:08, 33.42s/it]
# OMP Test Batch for noise_level = 0.01:   1%|▏         | 14/1000 [09:21<10:25:58, 38.09s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 10/1000 [09:22<15:42:22, 57.11s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 16/1000 [09:13<9:17:49, 34.01s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 10/1000 [09:19<15:42:04, 57.10s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 16/1000 [09:28<10:37:31, 38.87s/it]
# OMP Test Batch for noise_level = 0.04:   1%|▏         | 13/1000 [09:28<12:45:05, 46.51s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 15/1000 [09:27<9:02:13, 33.03s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 17/1000 [09:32<9:05:39, 33.31s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 16/1000 [09:35<9:04:07, 33.18s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 17/1000 [09:41<9:07:11, 33.40s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 17/1000 [09:38<8:51:52, 32.46s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 16/1000 [09:48<9:55:19, 36.30s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 17/1000 [09:44<9:00:03, 32.96s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 11/1000 [09:48<15:32:08, 56.55s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 15/1000 [09:53<10:21:12, 37.84s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 15/1000 [09:58<10:20:03, 37.77s/it]
# OMP Test Batch for noise_level = 0.06:   1%|▏         | 14/1000 [09:54<13:09:45, 48.06s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 17/1000 [10:02<10:14:06, 37.48s/it]
# OMP Test Batch for noise_level = 0.04:   1%|▏         | 14/1000 [10:03<11:43:38, 42.82s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 16/1000 [10:00<9:02:37, 33.09s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 17/1000 [10:06<8:55:54, 32.71s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 11/1000 [10:15<15:20:50, 55.86s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 18/1000 [10:13<9:00:29, 33.02s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 18/1000 [10:12<9:37:51, 35.31s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 17/1000 [10:19<9:31:51, 34.90s/it]
# OMP Test Batch for noise_level = 0.05:   1%|          | 12/1000 [10:18<15:35:38, 56.82s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 11/1000 [10:17<15:46:21, 57.41s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 18/1000 [10:15<9:13:39, 33.83s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 18/1000 [10:19<9:09:10, 33.55s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 18/1000 [10:37<10:00:48, 36.71s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 16/1000 [10:40<10:38:38, 38.94s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 15/1000 [10:38<11:07:46, 40.68s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 15/1000 [10:41<13:02:27, 47.66s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 18/1000 [10:42<9:07:19, 33.44s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 19/1000 [10:42<9:08:52, 33.57s/it]
# OMP Test Batch for noise_level = 0.12:   1%|          | 12/1000 [10:43<15:21:31, 55.96s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 18/1000 [10:52<9:18:53, 34.15s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 19/1000 [10:49<9:12:47, 33.81s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 19/1000 [10:56<9:28:50, 34.79s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 19/1000 [11:09<9:37:36, 35.33s/it]
# OMP Test Batch for noise_level = 0.02:   1%|          | 12/1000 [11:15<15:41:25, 57.17s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 17/1000 [11:16<10:26:32, 38.24s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 16/1000 [11:14<10:41:09, 39.09s/it]
# OMP Test Batch for noise_level = 0.05:   1%|▏         | 13/1000 [11:19<15:55:40, 58.10s/it]
# OMP Test Batch for noise_level = 0.09:   1%|          | 12/1000 [11:17<15:56:19, 58.08s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 19/1000 [11:16<9:12:30, 33.79s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 19/1000 [11:23<9:06:05, 33.40s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 20/1000 [11:17<9:15:35, 34.02s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 20/1000 [11:25<9:23:18, 34.49s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 17/1000 [11:31<12:02:27, 44.10s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 18/1000 [11:35<11:00:56, 40.38s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 20/1000 [11:45<9:39:17, 35.47s/it]
# OMP Test Batch for noise_level = 0.12:   1%|▏         | 13/1000 [11:39<15:21:11, 56.00s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 18/1000 [11:51<10:08:59, 37.21s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 17/1000 [11:50<10:23:43, 38.07s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 21/1000 [11:48<8:46:13, 32.25s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 20/1000 [11:51<9:17:14, 34.12s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 21/1000 [11:51<9:18:13, 34.21s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 20/1000 [11:51<11:04:38, 40.69s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 17/1000 [12:01<12:04:38, 44.23s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 21/1000 [12:11<10:21:42, 38.10s/it]
# OMP Test Batch for noise_level = 0.05:   1%|▏         | 14/1000 [12:21<16:11:23, 59.11s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 19/1000 [12:25<9:51:10, 36.16s/it]
# OMP Test Batch for noise_level = 0.09:   1%|▏         | 13/1000 [12:18<16:14:26, 59.24s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 18/1000 [12:22<12:34:47, 46.12s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 18/1000 [12:26<10:14:55, 37.57s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 19/1000 [12:22<11:33:22, 42.41s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 21/1000 [12:29<8:58:43, 33.02s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 22/1000 [12:22<8:54:47, 32.81s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 22/1000 [12:26<9:18:21, 34.25s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 21/1000 [12:27<9:25:32, 34.66s/it]
# OMP Test Batch for noise_level = 0.12:   1%|▏         | 14/1000 [12:41<15:51:24, 57.89s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 21/1000 [12:43<12:00:31, 44.16s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 22/1000 [12:55<9:38:36, 35.50s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 23/1000 [12:46<8:13:02, 30.28s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 22/1000 [12:53<10:40:35, 39.30s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 20/1000 [13:00<9:47:33, 35.97s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 22/1000 [13:01<8:56:01, 32.89s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 19/1000 [12:59<11:50:37, 43.46s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 19/1000 [13:02<10:05:22, 37.03s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 23/1000 [12:57<9:04:29, 33.44s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 22/1000 [13:03<9:33:33, 35.19s/it]
# OMP Test Batch for noise_level = 0.02:   1%|▏         | 14/1000 [13:16<16:07:45, 58.89s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 15/1000 [13:22<16:19:36, 59.67s/it]
# OMP Test Batch for noise_level = 0.09:   1%|▏         | 14/1000 [13:20<16:22:47, 59.81s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▏         | 24/1000 [13:20<8:27:59, 31.23s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 22/1000 [13:19<11:19:10, 41.67s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 19/1000 [13:27<11:41:50, 42.93s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 23/1000 [13:30<10:27:14, 38.52s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 21/1000 [13:36<9:45:39, 35.89s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 20/1000 [13:32<11:00:03, 40.41s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▏         | 24/1000 [13:29<8:57:12, 33.03s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 21/1000 [13:31<10:28:38, 38.53s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▏         | 23/1000 [13:41<10:27:40, 38.55s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 20/1000 [13:38<10:03:13, 36.93s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 15/1000 [13:35<15:28:08, 56.54s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 23/1000 [13:36<9:19:48, 34.38s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 23/1000 [13:47<9:59:43, 36.83s/it]
# OMP Test Batch for noise_level = 0.18:   2%|▎         | 25/1000 [13:51<8:27:10, 31.21s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 23/1000 [13:55<10:52:16, 40.06s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 21/1000 [14:02<10:07:36, 37.24s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 20/1000 [14:02<11:06:13, 40.79s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 22/1000 [14:04<9:57:54, 36.68s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▏         | 24/1000 [14:07<10:17:57, 37.99s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 22/1000 [14:13<9:49:05, 36.14s/it]
# OMP Test Batch for noise_level = 0.16:   2%|▎         | 25/1000 [14:05<9:09:02, 33.79s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 15/1000 [14:16<16:10:35, 59.12s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▏         | 24/1000 [14:10<9:17:34, 34.28s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 15/1000 [14:13<15:49:16, 57.82s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▏         | 24/1000 [14:21<9:41:34, 35.75s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 16/1000 [14:21<16:14:56, 59.45s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 26/1000 [14:24<8:37:06, 31.85s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 22/1000 [14:33<9:37:30, 35.43s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 21/1000 [14:34<10:19:54, 37.99s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▏         | 24/1000 [14:30<10:24:29, 38.39s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 16/1000 [14:33<15:36:36, 57.11s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 23/1000 [14:34<9:28:31, 34.92s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 23/1000 [14:44<9:26:41, 34.80s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 22/1000 [14:42<9:11:49, 33.85s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 26/1000 [14:38<9:03:23, 33.47s/it]
# OMP Test Batch for noise_level = 0.08:   2%|▎         | 25/1000 [14:41<9:58:23, 36.82s/it]
# OMP Test Batch for noise_level = 0.03:   2%|▎         | 25/1000 [14:50<9:08:24, 33.75s/it]
# OMP Test Batch for noise_level = 0.14:   2%|▎         | 25/1000 [14:43<9:12:54, 34.03s/it]
# OMP Test Batch for noise_level = 0.00:   2%|▎         | 25/1000 [14:53<10:03:40, 37.15s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 27/1000 [14:52<8:17:08, 30.66s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 16/1000 [15:04<15:14:34, 55.77s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 23/1000 [15:05<9:18:59, 34.33s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 22/1000 [15:06<9:50:29, 36.23s/it]
# OMP Test Batch for noise_level = 0.20:   2%|▎         | 25/1000 [15:00<9:45:09, 36.01s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 16/1000 [15:05<15:21:25, 56.18s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▏         | 24/1000 [15:05<9:08:00, 33.69s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 17/1000 [15:12<15:31:05, 56.83s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▏         | 24/1000 [15:16<9:10:59, 33.87s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▏         | 23/1000 [15:14<9:02:59, 33.35s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 27/1000 [15:09<8:52:04, 32.81s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 26/1000 [15:13<9:34:22, 35.38s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 26/1000 [15:18<8:42:54, 32.21s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 26/1000 [15:15<8:58:31, 33.17s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 26/1000 [15:24<9:31:34, 35.21s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 17/1000 [15:18<14:34:45, 53.39s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 28/1000 [15:21<8:08:18, 30.14s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 26/1000 [15:27<9:02:07, 33.40s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▏         | 24/1000 [15:35<8:55:47, 32.94s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 23/1000 [15:35<9:13:29, 33.99s/it]
# OMP Test Batch for noise_level = 0.10:   2%|▎         | 25/1000 [15:35<8:48:20, 32.51s/it]
# OMP Test Batch for noise_level = 0.01:   2%|▎         | 25/1000 [15:46<8:51:51, 32.73s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 27/1000 [15:46<8:20:07, 30.84s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 27/1000 [15:44<9:15:00, 34.22s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 17/1000 [15:50<14:28:19, 53.00s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 27/1000 [15:45<8:43:15, 32.27s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 27/1000 [15:55<9:11:39, 34.02s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 29/1000 [15:47<7:45:39, 28.77s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 17/1000 [15:51<14:28:35, 53.02s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 18/1000 [15:57<14:33:38, 53.38s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 27/1000 [15:56<8:39:18, 32.02s/it]
# OMP Test Batch for noise_level = 0.07:   2%|▎         | 25/1000 [16:04<8:39:02, 31.94s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 26/1000 [16:02<8:20:59, 30.86s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▏         | 24/1000 [16:05<8:56:16, 32.97s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 18/1000 [16:04<13:56:02, 51.08s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 29/1000 [16:06<8:11:54, 30.40s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 26/1000 [16:14<8:29:43, 31.40s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 28/1000 [16:14<8:06:11, 30.01s/it]
# OMP Test Batch for noise_level = 0.04:   2%|▎         | 25/1000 [16:14<8:32:05, 31.51s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 28/1000 [16:14<8:50:51, 32.77s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 28/1000 [16:14<8:27:18, 31.32s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 28/1000 [16:24<8:46:05, 32.48s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 18/1000 [16:33<13:37:30, 49.95s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 19/1000 [16:32<13:04:07, 47.96s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 28/1000 [16:25<8:20:13, 30.88s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 27/1000 [16:30<8:04:53, 29.90s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 26/1000 [16:33<8:22:06, 30.93s/it]
# OMP Test Batch for noise_level = 0.06:   2%|▎         | 25/1000 [16:33<8:30:20, 31.41s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 18/1000 [16:34<13:39:18, 50.06s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 30/1000 [16:33<7:57:39, 29.55s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 29/1000 [16:41<7:50:34, 29.08s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 27/1000 [16:43<8:14:58, 30.52s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 29/1000 [16:41<8:23:13, 31.10s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 31/1000 [16:39<7:24:27, 27.52s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 29/1000 [16:43<8:14:06, 30.53s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 29/1000 [16:53<8:27:23, 31.35s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 19/1000 [16:46<13:14:13, 48.58s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 29/1000 [16:53<8:07:51, 30.15s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 28/1000 [16:58<7:55:44, 29.37s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 26/1000 [17:01<8:12:40, 30.35s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 30/1000 [17:07<7:35:35, 28.18s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 31/1000 [17:02<7:52:07, 29.23s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 27/1000 [17:09<8:00:13, 29.61s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 32/1000 [17:05<7:16:30, 27.06s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 30/1000 [17:10<8:11:05, 30.38s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 28/1000 [17:16<8:25:18, 31.19s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 20/1000 [17:13<12:30:32, 45.95s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 30/1000 [17:18<7:56:36, 29.48s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 30/1000 [17:10<7:59:43, 29.67s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 19/1000 [17:14<12:48:21, 46.99s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 30/1000 [17:16<7:33:09, 28.03s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 28/1000 [17:25<7:38:57, 28.33s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 29/1000 [17:24<7:40:37, 28.46s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 27/1000 [17:28<7:54:57, 29.29s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 20/1000 [17:25<12:25:34, 45.65s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 31/1000 [17:32<7:20:16, 27.26s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 33/1000 [17:28<6:58:43, 25.98s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 31/1000 [17:35<7:45:14, 28.81s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 32/1000 [17:33<8:00:15, 29.77s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 31/1000 [17:44<7:39:13, 28.43s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 31/1000 [17:36<7:42:42, 28.65s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 29/1000 [17:46<8:19:27, 30.86s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 20/1000 [17:53<12:07:16, 44.53s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 31/1000 [17:43<7:26:16, 27.63s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 21/1000 [17:51<11:49:34, 43.49s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 29/1000 [17:52<7:31:24, 27.89s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 30/1000 [17:50<7:28:03, 27.71s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 32/1000 [17:56<7:05:07, 26.35s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 20/1000 [17:52<12:03:52, 44.32s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 28/1000 [17:55<7:44:51, 28.70s/it]
# OMP Test Batch for noise_level = 0.18:   3%|▎         | 34/1000 [17:54<6:56:35, 25.87s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 33/1000 [17:56<7:27:18, 27.75s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 29/1000 [18:02<7:35:33, 28.15s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 30/1000 [18:08<7:38:26, 28.36s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 32/1000 [18:02<7:28:50, 27.82s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 32/1000 [18:08<7:14:38, 26.94s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 33/1000 [18:18<6:42:40, 24.99s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 31/1000 [18:16<7:19:13, 27.20s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▎         | 35/1000 [18:15<6:32:43, 24.42s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 29/1000 [18:21<7:32:31, 27.96s/it]
# OMP Test Batch for noise_level = 0.16:   3%|▎         | 34/1000 [18:18<7:00:43, 26.13s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 33/1000 [18:22<7:02:58, 26.24s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 33/1000 [18:30<6:55:27, 25.78s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 21/1000 [18:29<11:28:06, 42.17s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 30/1000 [18:28<7:23:36, 27.44s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 22/1000 [18:28<11:16:56, 41.53s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 31/1000 [18:33<7:18:48, 27.17s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 21/1000 [18:28<11:24:15, 41.94s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 33/1000 [18:29<7:21:31, 27.40s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 33/1000 [18:29<6:46:28, 25.22s/it]
# OMP Test Batch for noise_level = 0.03:   3%|▎         | 34/1000 [18:41<6:32:26, 24.38s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 31/1000 [18:41<7:04:03, 26.26s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 22/1000 [18:40<11:17:21, 41.56s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 32/1000 [18:42<7:14:02, 26.90s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▎         | 36/1000 [18:42<6:44:35, 25.18s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▎         | 35/1000 [18:45<7:02:34, 26.27s/it]
# OMP Test Batch for noise_level = 0.08:   3%|▎         | 34/1000 [18:49<7:03:15, 26.29s/it]
# OMP Test Batch for noise_level = 0.00:   3%|▎         | 34/1000 [18:56<7:00:00, 26.09s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 31/1000 [18:55<7:20:14, 27.26s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 32/1000 [18:59<7:13:09, 26.85s/it]
# OMP Test Batch for noise_level = 0.14:   3%|▎         | 34/1000 [18:55<7:17:38, 27.18s/it]
# OMP Test Batch for noise_level = 0.20:   3%|▎         | 34/1000 [18:57<6:57:37, 25.94s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 22/1000 [19:08<11:09:08, 41.05s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▏         | 23/1000 [19:07<11:01:38, 40.63s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 33/1000 [19:04<6:48:15, 25.33s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 32/1000 [19:07<7:05:50, 26.39s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 22/1000 [19:06<11:03:59, 40.74s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▎         | 36/1000 [19:11<7:00:25, 26.17s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 31/1000 [19:15<7:23:18, 27.45s/it]
# OMP Test Batch for noise_level = 0.08:   4%|▎         | 35/1000 [19:16<7:06:12, 26.50s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▏         | 23/1000 [19:15<10:40:52, 39.36s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 33/1000 [19:23<7:02:15, 26.20s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 32/1000 [19:21<7:14:45, 26.95s/it]
# OMP Test Batch for noise_level = 0.14:   4%|▎         | 35/1000 [19:21<7:09:52, 26.73s/it]
# OMP Test Batch for noise_level = 0.03:   4%|▎         | 36/1000 [19:29<6:26:44, 24.07s/it]
# OMP Test Batch for noise_level = 0.20:   4%|▎         | 35/1000 [19:22<6:51:08, 25.56s/it]
# OMP Test Batch for noise_level = 0.10:   3%|▎         | 34/1000 [19:28<6:40:03, 24.85s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 33/1000 [19:32<6:57:07, 25.88s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▎         | 37/1000 [19:30<6:29:16, 24.25s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▍         | 38/1000 [19:30<6:30:33, 24.36s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 23/1000 [19:41<10:30:57, 38.75s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 32/1000 [19:38<7:01:05, 26.10s/it]
# OMP Test Batch for noise_level = 0.08:   4%|▎         | 36/1000 [19:39<6:50:01, 25.52s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 23/1000 [19:39<10:22:31, 38.23s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 33/1000 [19:45<6:56:54, 25.87s/it]
# OMP Test Batch for noise_level = 0.14:   4%|▎         | 36/1000 [19:41<6:36:01, 24.65s/it]
# OMP Test Batch for noise_level = 0.03:   4%|▎         | 37/1000 [19:49<6:08:06, 22.93s/it]
# OMP Test Batch for noise_level = 0.01:   3%|▎         | 34/1000 [19:54<7:20:47, 27.38s/it]
# OMP Test Batch for noise_level = 0.00:   4%|▎         | 36/1000 [19:55<7:28:17, 27.90s/it]
# OMP Test Batch for noise_level = 0.10:   4%|▎         | 35/1000 [19:49<6:25:08, 23.95s/it]
# OMP Test Batch for noise_level = 0.07:   3%|▎         | 34/1000 [19:54<6:35:55, 24.59s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▍         | 38/1000 [19:50<6:07:28, 22.92s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▍         | 39/1000 [19:52<6:20:11, 23.74s/it]
# OMP Test Batch for noise_level = 0.06:   3%|▎         | 33/1000 [19:59<6:36:35, 24.61s/it]
# OMP Test Batch for noise_level = 0.08:   4%|▎         | 37/1000 [20:00<6:28:06, 24.18s/it]
# OMP Test Batch for noise_level = 0.14:   4%|▎         | 37/1000 [20:00<6:09:01, 22.99s/it]
# OMP Test Batch for noise_level = 0.04:   3%|▎         | 34/1000 [20:06<6:34:51, 24.53s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▏         | 24/1000 [20:10<9:42:56, 35.84s/it]
# OMP Test Batch for noise_level = 0.03:   4%|▍         | 38/1000 [20:10<5:56:25, 22.23s/it]
# OMP Test Batch for noise_level = 0.05:   2%|▎         | 25/1000 [20:09<9:38:00, 35.57s/it]
# OMP Test Batch for noise_level = 0.09:   2%|▏         | 24/1000 [20:07<9:31:06, 35.11s/it]
# OMP Test Batch for noise_level = 0.20:   4%|▎         | 37/1000 [20:04<6:16:00, 23.43s/it]
# OMP Test Batch for noise_level = 0.12:   2%|▎         | 25/1000 [20:09<8:50:54, 32.67s/it]
# OMP Test Batch for noise_level = 0.10:   4%|▎         | 36/1000 [20:10<6:06:55, 22.84s/it]
# OMP Test Batch for noise_level = 0.07:   4%|▎         | 35/1000 [20:14<6:16:57, 23.44s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▍         | 39/1000 [20:11<5:57:04, 22.29s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▍         | 40/1000 [20:14<6:09:03, 23.07s/it]
# OMP Test Batch for noise_level = 0.01:   4%|▎         | 35/1000 [20:26<7:44:13, 28.86s/it]
# OMP Test Batch for noise_level = 0.00:   4%|▎         | 37/1000 [20:27<7:46:21, 29.06s/it]
# OMP Test Batch for noise_level = 0.08:   4%|▍         | 38/1000 [20:22<6:15:32, 23.42s/it]
# OMP Test Batch for noise_level = 0.14:   4%|▍         | 38/1000 [20:20<5:52:09, 21.96s/it]
# OMP Test Batch for noise_level = 0.04:   4%|▎         | 35/1000 [20:27<6:17:48, 23.49s/it]
# OMP Test Batch for noise_level = 0.03:   4%|▍         | 39/1000 [20:30<5:47:18, 21.68s/it]
# OMP Test Batch for noise_level = 0.02:   2%|▎         | 25/1000 [20:35<8:47:02, 32.43s/it]
# OMP Test Batch for noise_level = 0.20:   4%|▍         | 38/1000 [20:25<6:03:39, 22.68s/it]
# OMP Test Batch for noise_level = 0.10:   4%|▎         | 37/1000 [20:30<5:54:24, 22.08s/it]
# OMP Test Batch for noise_level = 0.07:   4%|▎         | 36/1000 [20:34<5:56:57, 22.22s/it]
# OMP Test Batch for noise_level = 0.05:   3%|▎         | 26/1000 [20:36<8:55:27, 32.98s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▍         | 40/1000 [20:32<5:48:17, 21.77s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▍         | 41/1000 [20:33<5:48:28, 21.80s/it]
# OMP Test Batch for noise_level = 0.12:   3%|▎         | 26/1000 [20:36<8:22:36, 30.96s/it]
# OMP Test Batch for noise_level = 0.06:   4%|▎         | 35/1000 [20:42<6:07:29, 22.85s/it]
# OMP Test Batch for noise_level = 0.08:   4%|▍         | 39/1000 [20:42<6:01:52, 22.59s/it]
# OMP Test Batch for noise_level = 0.04:   4%|▎         | 36/1000 [20:48<6:02:58, 22.59s/it]
# OMP Test Batch for noise_level = 0.03:   4%|▍         | 40/1000 [20:50<5:38:52, 21.18s/it]
# OMP Test Batch for noise_level = 0.10:   4%|▍         | 38/1000 [20:50<5:42:04, 21.33s/it]
# OMP Test Batch for noise_level = 0.01:   4%|▎         | 36/1000 [20:58<7:57:16, 29.71s/it]
# OMP Test Batch for noise_level = 0.16:   4%|▍         | 41/1000 [20:52<5:41:44, 21.38s/it]
# OMP Test Batch for noise_level = 0.09:   3%|▎         | 26/1000 [20:56<8:01:58, 29.69s/it]
# OMP Test Batch for noise_level = 0.18:   4%|▍         | 42/1000 [20:53<5:42:14, 21.43s/it]
# OMP Test Batch for noise_level = 0.05:   3%|▎         | 27/1000 [21:01<8:17:28, 30.68s/it]
# OMP Test Batch for noise_level = 0.06:   4%|▎         | 36/1000 [21:02<5:54:31, 22.07s/it]
# ...
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 988/1000 [3:20:32<01:24,  7.00s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 977/1000 [3:20:31<02:46,  7.23s/it]
# OMP Test Batch for noise_level = 0.14:  99%|█████████▉| 992/1000 [3:20:28<00:55,  6.88s/it]
# OMP Test Batch for noise_level = 0.18:  99%|█████████▉| 993/1000 [3:20:27<00:47,  6.83s/it]
# OMP Test Batch for noise_level = 0.03:  99%|█████████▉| 991/1000 [3:20:37<01:04,  7.17s/it]
# OMP Test Batch for noise_level = 0.20: 100%|█████████▉| 997/1000 [3:20:29<00:21,  7.27s/it]
# OMP Test Batch for noise_level = 0.16:  99%|█████████▉| 993/1000 [3:20:31<00:49,  7.04s/it]
# OMP Test Batch for noise_level = 0.00: 100%|█████████▉| 998/1000 [3:20:41<00:13,  6.76s/it]
# OMP Test Batch for noise_level = 0.08:  96%|█████████▌| 962/1000 [3:20:36<04:25,  6.99s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 989/1000 [3:20:39<01:17,  7.01s/it]
# OMP Test Batch for noise_level = 0.14:  99%|█████████▉| 993/1000 [3:20:34<00:47,  6.73s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 978/1000 [3:20:38<02:39,  7.24s/it]
# OMP Test Batch for noise_level = 0.18:  99%|█████████▉| 994/1000 [3:20:34<00:41,  7.00s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 980/1000 [3:20:46<02:16,  6.85s/it]
# OMP Test Batch for noise_level = 0.10:  98%|█████████▊| 981/1000 [3:20:39<02:13,  7.00s/it]
# OMP Test Batch for noise_level = 0.20: 100%|█████████▉| 998/1000 [3:20:35<00:14,  7.09s/it]
# OMP Test Batch for noise_level = 0.16:  99%|█████████▉| 994/1000 [3:20:39<00:42,  7.11s/it]
# OMP Test Batch for noise_level = 0.00: 100%|█████████▉| 999/1000 [3:20:48<00:06,  6.80s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 990/1000 [3:20:46<01:10,  7.02s/it]
# OMP Test Batch for noise_level = 0.14:  99%|█████████▉| 994/1000 [3:20:41<00:40,  6.80s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 979/1000 [3:20:46<02:32,  7.25s/it]
# OMP Test Batch for noise_level = 0.18: 100%|█████████▉| 995/1000 [3:20:41<00:34,  6.88s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 981/1000 [3:20:53<02:10,  6.87s/it]
# OMP Test Batch for noise_level = 0.03:  99%|█████████▉| 993/1000 [3:20:52<00:50,  7.16s/it]
# OMP Test Batch for noise_level = 0.20: 100%|█████████▉| 999/1000 [3:20:43<00:07,  7.15s/it]
# OMP Test Batch for noise_level = 0.16: 100%|█████████▉| 995/1000 [3:20:45<00:34,  6.98s/it]
# OMP Test Batch for noise_level = 0.00: 100%|██████████| 1000/1000 [3:20:55<00:00, 12.06s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 991/1000 [3:20:52<01:01,  6.82s/it]
# OMP Test Batch for noise_level = 0.08:  96%|█████████▋| 964/1000 [3:20:50<04:12,  7.01s/it]
# OMP Test Batch for noise_level = 0.14: 100%|█████████▉| 995/1000 [3:20:48<00:34,  6.82s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 980/1000 [3:20:53<02:25,  7.26s/it]
# OMP Test Batch for noise_level = 0.18: 100%|█████████▉| 996/1000 [3:20:48<00:28,  7.00s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 982/1000 [3:20:59<02:02,  6.81s/it]
# OMP Test Batch for noise_level = 0.20: 100%|██████████| 1000/1000 [3:20:49<00:00, 12.05s/it]
# OMP Test Batch for noise_level = 0.03:  99%|█████████▉| 994/1000 [3:20:59<00:43,  7.17s/it]
# OMP Test Batch for noise_level = 0.10:  98%|█████████▊| 983/1000 [3:20:53<02:01,  7.14s/it]
# OMP Test Batch for noise_level = 0.16: 100%|█████████▉| 996/1000 [3:20:53<00:28,  7.06s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 992/1000 [3:20:59<00:54,  6.77s/it]
# OMP Test Batch for noise_level = 0.08:  96%|█████████▋| 965/1000 [3:20:56<04:02,  6.91s/it]
# OMP Test Batch for noise_level = 0.14: 100%|█████████▉| 996/1000 [3:20:55<00:27,  6.75s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 981/1000 [3:21:00<02:16,  7.18s/it]
# OMP Test Batch for noise_level = 0.18: 100%|█████████▉| 997/1000 [3:20:55<00:20,  6.99s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 983/1000 [3:21:06<01:54,  6.74s/it]
# OMP Test Batch for noise_level = 0.03: 100%|█████████▉| 995/1000 [3:21:05<00:34,  6.85s/it]
# OMP Test Batch for noise_level = 0.10:  98%|█████████▊| 984/1000 [3:21:00<01:49,  6.87s/it]
# OMP Test Batch for noise_level = 0.16: 100%|█████████▉| 997/1000 [3:20:59<00:20,  6.81s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 993/1000 [3:21:06<00:47,  6.73s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 966/1000 [3:21:03<03:52,  6.85s/it]
# OMP Test Batch for noise_level = 0.14: 100%|█████████▉| 997/1000 [3:21:01<00:20,  6.70s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 982/1000 [3:21:06<02:04,  6.90s/it]
# OMP Test Batch for noise_level = 0.18: 100%|█████████▉| 998/1000 [3:21:01<00:13,  6.77s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 984/1000 [3:21:12<01:46,  6.68s/it]
# OMP Test Batch for noise_level = 0.03: 100%|█████████▉| 996/1000 [3:21:12<00:27,  6.81s/it]
# OMP Test Batch for noise_level = 0.04:  99%|█████████▉| 994/1000 [3:21:12<00:39,  6.53s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 967/1000 [3:21:10<03:44,  6.80s/it]
# OMP Test Batch for noise_level = 0.14: 100%|█████████▉| 998/1000 [3:21:08<00:13,  6.67s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 983/1000 [3:21:13<01:57,  6.89s/it]
# OMP Test Batch for noise_level = 0.18: 100%|█████████▉| 999/1000 [3:21:08<00:06,  6.81s/it]
# OMP Test Batch for noise_level = 0.01:  98%|█████████▊| 985/1000 [3:21:19<01:39,  6.65s/it]
# OMP Test Batch for noise_level = 0.03: 100%|█████████▉| 997/1000 [3:21:18<00:20,  6.79s/it]
# OMP Test Batch for noise_level = 0.16: 100%|█████████▉| 999/1000 [3:21:12<00:06,  6.80s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 968/1000 [3:21:16<03:31,  6.60s/it]
# OMP Test Batch for noise_level = 0.14: 100%|█████████▉| 999/1000 [3:21:15<00:06,  6.64s/it]
# OMP Test Batch for noise_level = 0.18: 100%|██████████| 1000/1000 [3:21:14<00:00, 12.07s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 984/1000 [3:21:20<01:49,  6.87s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▊| 986/1000 [3:21:25<01:30,  6.45s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▊| 987/1000 [3:21:18<01:22,  6.38s/it]
# OMP Test Batch for noise_level = 0.03: 100%|█████████▉| 998/1000 [3:21:25<00:13,  6.73s/it]
# OMP Test Batch for noise_level = 0.04: 100%|█████████▉| 996/1000 [3:21:24<00:25,  6.41s/it]
# OMP Test Batch for noise_level = 0.16: 100%|██████████| 1000/1000 [3:21:19<00:00, 12.08s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 969/1000 [3:21:22<03:19,  6.44s/it]
# OMP Test Batch for noise_level = 0.14: 100%|██████████| 1000/1000 [3:21:21<00:00, 12.08s/it]
# OMP Test Batch for noise_level = 0.07:  98%|█████████▊| 985/1000 [3:21:26<01:40,  6.71s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▊| 987/1000 [3:21:31<01:21,  6.29s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 988/1000 [3:21:25<01:16,  6.34s/it]
# OMP Test Batch for noise_level = 0.03: 100%|█████████▉| 999/1000 [3:21:31<00:06,  6.55s/it]
# OMP Test Batch for noise_level = 0.04: 100%|█████████▉| 997/1000 [3:21:31<00:19,  6.41s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 970/1000 [3:21:28<03:13,  6.45s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▊| 986/1000 [3:21:32<01:31,  6.54s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 988/1000 [3:21:37<01:15,  6.29s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 989/1000 [3:21:31<01:09,  6.29s/it]
# OMP Test Batch for noise_level = 0.03: 100%|██████████| 1000/1000 [3:21:37<00:00, 12.10s/it]
# OMP Test Batch for noise_level = 0.04: 100%|█████████▉| 998/1000 [3:21:37<00:12,  6.38s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 971/1000 [3:21:35<03:06,  6.43s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▊| 987/1000 [3:21:38<01:22,  6.37s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 990/1000 [3:21:36<01:00,  6.03s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 989/1000 [3:21:44<01:09,  6.29s/it]
# OMP Test Batch for noise_level = 0.04: 100%|█████████▉| 999/1000 [3:21:43<00:06,  6.36s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 972/1000 [3:21:41<02:59,  6.42s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 988/1000 [3:21:44<01:14,  6.22s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 991/1000 [3:21:42<00:53,  5.98s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 990/1000 [3:21:50<01:02,  6.28s/it]
# OMP Test Batch for noise_level = 0.04: 100%|██████████| 1000/1000 [3:21:49<00:00, 12.11s/it]
# OMP Test Batch for noise_level = 0.08:  97%|█████████▋| 973/1000 [3:21:48<02:52,  6.39s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 989/1000 [3:21:50<01:07,  6.11s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 992/1000 [3:21:48<00:47,  5.95s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 991/1000 [3:21:55<00:54,  6.06s/it]
# OMP Test Batch for noise_level = 0.10:  99%|█████████▉| 993/1000 [3:21:52<00:38,  5.47s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 990/1000 [3:21:56<01:00,  6.04s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 992/1000 [3:22:01<00:48,  6.03s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 975/1000 [3:22:00<02:35,  6.23s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 991/1000 [3:22:02<00:53,  5.98s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 993/1000 [3:22:07<00:42,  6.01s/it]
# OMP Test Batch for noise_level = 0.10: 100%|█████████▉| 995/1000 [3:22:04<00:28,  5.68s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 976/1000 [3:22:06<02:28,  6.18s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 992/1000 [3:22:08<00:47,  5.95s/it]
# OMP Test Batch for noise_level = 0.01:  99%|█████████▉| 994/1000 [3:22:13<00:35,  5.98s/it]
# OMP Test Batch for noise_level = 0.10: 100%|█████████▉| 996/1000 [3:22:10<00:22,  5.74s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 977/1000 [3:22:12<02:21,  6.15s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 993/1000 [3:22:14<00:41,  5.92s/it]
# OMP Test Batch for noise_level = 0.01: 100%|█████████▉| 995/1000 [3:22:19<00:29,  5.98s/it]
# OMP Test Batch for noise_level = 0.10: 100%|█████████▉| 997/1000 [3:22:16<00:17,  5.78s/it]
# OMP Test Batch for noise_level = 0.07:  99%|█████████▉| 994/1000 [3:22:19<00:35,  5.91s/it]
# OMP Test Batch for noise_level = 0.01: 100%|█████████▉| 996/1000 [3:22:25<00:23,  5.97s/it]
# OMP Test Batch for noise_level = 0.10: 100%|█████████▉| 998/1000 [3:22:22<00:11,  5.80s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 979/1000 [3:22:24<02:08,  6.11s/it]
# OMP Test Batch for noise_level = 0.01: 100%|█████████▉| 997/1000 [3:22:31<00:17,  5.96s/it]
# OMP Test Batch for noise_level = 0.10: 100%|█████████▉| 999/1000 [3:22:27<00:05,  5.82s/it]
# OMP Test Batch for noise_level = 0.07: 100%|█████████▉| 996/1000 [3:22:31<00:23,  5.88s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 980/1000 [3:22:30<02:01,  6.10s/it]
# OMP Test Batch for noise_level = 0.01: 100%|█████████▉| 998/1000 [3:22:37<00:11,  5.97s/it]
# OMP Test Batch for noise_level = 0.10: 100%|██████████| 1000/1000 [3:22:33<00:00, 12.15s/it]
# OMP Test Batch for noise_level = 0.07: 100%|█████████▉| 997/1000 [3:22:37<00:17,  5.72s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 981/1000 [3:22:36<01:55,  6.09s/it]
# OMP Test Batch for noise_level = 0.01: 100%|█████████▉| 999/1000 [3:22:43<00:05,  5.96s/it]
# OMP Test Batch for noise_level = 0.07: 100%|█████████▉| 998/1000 [3:22:42<00:11,  5.64s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 982/1000 [3:22:42<01:46,  5.93s/it]
# OMP Test Batch for noise_level = 0.01: 100%|██████████| 1000/1000 [3:22:49<00:00, 12.17s/it]
# OMP Test Batch for noise_level = 0.07: 100%|█████████▉| 999/1000 [3:22:47<00:05,  5.59s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 983/1000 [3:22:47<01:37,  5.75s/it]
# OMP Test Batch for noise_level = 0.07: 100%|██████████| 1000/1000 [3:22:53<00:00, 12.17s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 984/1000 [3:22:53<01:31,  5.73s/it]
# OMP Test Batch for noise_level = 0.08:  98%|█████████▊| 985/1000 [3:22:58<01:25,  5.71s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▊| 986/1000 [3:23:04<01:19,  5.70s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▊| 987/1000 [3:23:09<01:12,  5.54s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 988/1000 [3:23:15<01:06,  5.58s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 989/1000 [3:23:21<01:01,  5.61s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 990/1000 [3:23:26<00:56,  5.62s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 991/1000 [3:23:32<00:50,  5.64s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 992/1000 [3:23:38<00:45,  5.65s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 993/1000 [3:23:42<00:37,  5.35s/it]
# OMP Test Batch for noise_level = 0.08:  99%|█████████▉| 994/1000 [3:23:48<00:32,  5.45s/it]
# OMP Test Batch for noise_level = 0.08: 100%|█████████▉| 995/1000 [3:23:54<00:27,  5.52s/it]
# OMP Test Batch for noise_level = 0.08: 100%|█████████▉| 996/1000 [3:23:59<00:22,  5.56s/it]
# OMP Test Batch for noise_level = 0.08: 100%|█████████▉| 997/1000 [3:24:05<00:16,  5.59s/it]
# OMP Test Batch for noise_level = 0.08: 100%|█████████▉| 998/1000 [3:24:10<00:11,  5.61s/it]
# OMP Test Batch for noise_level = 0.08: 100%|█████████▉| 999/1000 [3:24:16<00:05,  5.62s/it]
# OMP Test Batch for noise_level = 0.08: 100%|██████████| 1000/1000 [3:24:22<00:00, 12.26s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 positionErrors3_100 = dictionary.ompPositionErrorPipeline(sparsity_level=3, batch_size=1000, cores=50, verbose=False)
#
# File ~/csc/src/csc/dictionary.py:329, in ZSDictionary.ompPositionErrorPipeline(self, sparsity_level, batch_size, cores, verbose)
#     327 # Convertir les résultats en JSON et les enregistrer dans un fichier
#     328 with open(f'output_posErrPipeline_s{sparsity_level}_b{batch_size}.json', 'w') as json_file:
# --> 329     json.dump(results_dict, json_file, indent=4)
#     330 return results_dict
#
# File /usr/lib/python3.11/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File /usr/lib/python3.11/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File /usr/lib/python3.11/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File /usr/lib/python3.11/json/encoder.py:377, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     375     continue
#     376 else:
# --> 377     raise TypeError(f'keys must be str, int, float, bool or None, '
#     378                     f'not {key.__class__.__name__}')
#     379 if first:
#     380     first = False
#
# TypeError: keys must be str, int, float, bool or None, not int64

# %%
plt.figure(figsize=(10, 6))

# Pre-processing
results_dict = positionErrors3_100
# Génère des couleurs
colors = plt.cm.viridis(np.linspace(0, 1, len(results_dict)))  

# Définition des bins pour les erreurs de position
max_error = max(max(counter.keys()) for counter in results_dict.values())
min_error = min(min(counter.keys()) for counter in results_dict.values())
bins = np.arange(min_error, max_error + 50, 50)  # Création des bins de 50 unités

# Parcourir le dictionnaire de résultats et dessiner un histogramme pour chaque niveau de bruit
for (noise_level, counter), color in zip(results_dict.items(), colors):
    # Regroupement des erreurs par bins
    errors, counts = zip(*counter.items())
    summed_counts, _ = np.histogram(errors, bins=bins, weights=counts)
    
    # Normaliser pour faire un histogramme de densité
    summed_counts = summed_counts / sum(summed_counts)

    # Dessiner l'histogramme de densité
    plt.bar(bins[:-1], summed_counts, color=color, alpha=0.8, label=f'Noise {noise_level:.2f}', width=45)

plt.title('3 atoms/signal & 20 signals/batch')
plt.xlabel('Position Error')
plt.ylabel('Density')
plt.xticks(bins)  # Définir les ticks sur les bins
plt.legend(title="Noise Levels")
plt.grid(True)
plt.show()
