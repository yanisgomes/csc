# %%
import json
import numpy as np
from tqdm import tqdm
from itertools import product
import matplotlib.pyplot as plt

from csc.utils import *
from csc.atoms import *
from csc.workbench import *
from csc.dictionary import *

# Atom parameters
bmin = 0.005
bmax = 0.60
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.01
ymax = 0.034
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 1428 different atoms

# %% [markdown]
# ### Workbench initialization with a database path

# %%
batchSize = 200
path_to_signals_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\data_signals_{batchSize}.json'
path_to_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\data_omp_{batchSize}.json'
path_to_long_signals_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\deprecated\\signals_db{batchSize}.json'
path_to_long_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\\\deprecated\\omp_db{batchSize}.json'

#path_to_signals_db = f'/home/gomes/synthetic-data/omp_db200.json'
#path_to_omp_db = f'/home/gomes/synthetic-data/signals_db200.json'
workbench_old = CSCWorkbench(path_to_long_signals_db)
workbench_old.load_data()
workbench_old.set_dictionary(dictionary)

workbench_new = CSCWorkbench(path_to_signals_db)
workbench_new.load_data()
workbench_new.set_dictionary(dictionary)

# %%
workbench_old.plotMeanPosErr(path_to_long_omp_db)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotMeanPosErr(path_to_omp_db)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtSparsity(path_to_omp_db, sparsity=3)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtSparsity(path_to_omp_db, sparsity=4)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtSparsity(path_to_omp_db, sparsity=5)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtStep(path_to_omp_db, step=1)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtStep(path_to_omp_db, step=2)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtStep(path_to_omp_db, step=3)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtStep(path_to_omp_db, step=4)
# Out:
# signals_data : 3000
# output_data : 3000

# %%
workbench_new.plotPosErrAtStep(path_to_omp_db, step=5)
# Out:
# signals_data : 3000
# output_data : 3000
