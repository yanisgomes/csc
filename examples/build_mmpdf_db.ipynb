# %%
import json
import numpy as np
from tqdm import tqdm
from csc.utils import *
from csc.atoms import *
from csc.dictionary import *
from itertools import product
import matplotlib.pyplot as plt


# Atom parameters
bmin = 0.005
bmax = 0.60
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.01
ymax = 0.034
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 1428 different atoms

# %%
batchSize = 1
input_signals_db = f'/home/gomes/synthetic-data/deprecated/signals_db{batchSize}.json'
output_omp_db = f'/home/gomes/synthetic-data/test_mmpdf_{batchSize}.json'

# %%
dictionary.mmpdfPipelineFromDB(input_signals_db, output_omp_db, nb_cores=70, verbose=False)
# Out:
# OMP Pipeline from /home/gomes/synthetic-data/signals_db10.json with 150 signals
# OMP Pipeline from DB:   0%|          | 0/150 [00:00<?, ?it/s]
# OMP 1/3
# OMP 1/3
# OMP 1/3
# OMP 1/3
# OMP 1/3
# OMP 1/3
# OMP 1/3
# OMP 2/3
# OMP 1/3
# OMP 2/3
# OMP 1/3
# OMP 2/3
# OMP 1/3
# OMP 1/4
# OMP 2/3
# OMP 1/4
# OMP 2/3
# OMP 1/4
# OMP 2/3
# OMP 1/4
# OMP 1/4
# OMP 2/3
# OMP 2/3
# OMP 1/4
# OMP 3/3
# OMP 1/4
# OMP 2/3
# OMP 1/4
# OMP 2/4
# OMP 2/3
# OMP 1/4
# OMP 1/4
# OMP 2/4
# OMP 3/3
# OMP 3/3
# OMP 2/4
# OMP 1/5
# OMP 2/4
# OMP 3/3
# OMP 2/4
# OMP 1/5
# OMP 3/3
# OMP 2/4
# OMP 2/4
# OMP 3/3
# OMP 1/5
# OMP 3/3
# OMP Pipeline from DB:  67%|██████▋   | 100/150 [00:09<00:04, 10.87it/s]
# OMP 2/4
# OMP 1/5
# OMP 2/4
# OMP 3/3
# OMP 3/4
# OMP 1/5
# OMP 2/4
# OMP 2/5
# OMP 3/3
# OMP 1/5
# OMP 1/5
# OMP 2/5
# OMP 3/3
# OMP 1/5
# OMP 3/4
# OMP 2/5
# OMP 1/5
# OMP 3/4
# OMP 1/5
# OMP 2/5
# OMP 3/4
# OMP 3/4
# OMP 2/5
# OMP 1/3
# OMP 3/4
# OMP 1/3
# OMP 3/4
# OMP 3/4
# OMP 2/5
# OMP 1/3
# OMP 1/3
# ...
