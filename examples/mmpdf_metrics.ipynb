# %%
import json
import numpy as np
from tqdm import tqdm
from itertools import product
import matplotlib.pyplot as plt

from csc.utils import *
from csc.atoms import *
from csc.workbench import *
from csc.dictionary import *

# Atom parameters
bmin = 0.005
bmax = 0.60
b_step = 0.005
b_values = np.arange(bmin, bmax, b_step)

ymin = 0.01
ymax = 0.034
y_step = 0.002
y_values = np.arange(ymin, ymax, y_step)

s_values = [1]

dictionary = ZSDictionary.from_values(b_values, y_values, s_values)
print('The dictionary has {} different atoms'.format(len(dictionary)))
# Out:
# The dictionary has 1428 different atoms

# %% [markdown]
# ### Workbench initialization with a database path

# %%
batchSize = 200
path_to_signals_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\data_signals_{batchSize}.json'
path_to_omp_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\data_omp_{batchSize}.json'
path_to_mmpdf_db = f'C:\\Users\\gomes\\Documents\\ENS\\00_M1\\00_BORELLI\\01_WorkInProgress\\\synthetic-data\\data_mmpdf_{batchSize}.json'

workbench = CSCWorkbench(path_to_signals_db)
workbench.set_dictionary(dictionary)
workbench.load_data()

# %%
workbench.plotMMPDFPosErrComparison(path_to_mmpdf_db)

# %%
workbench.plotMMPDFScoreF1Gloabl(path_to_mmpdf_db)

# %%
workbench.plotMMPDFScoreF1Gloabl(path_to_mmpdf_db, matching_type='matchingPosition', f1_type='f1Correlation')

# %%
workbench.plotMMPDFScoreF1Gloabl(path_to_mmpdf_db, matching_type='matchingCorrelation', f1_type='f1Correlation')

# %% [markdown]
# ## Matching en position

# %% [markdown]
# #### F1 position

# %%
workbench.plotMMPDFScoreF1(path_to_mmpdf_db, matching_type='matchingPosition', f1_type='f1Position')

# %% [markdown]
# #### F1 corrélation

# %%
workbench.plotMMPDFScoreF1(path_to_mmpdf_db, matching_type='matchingPosition', f1_type='f1Correlation')

# %% [markdown]
# ## Matching en corrélation

# %% [markdown]
# #### F1 position

# %%
workbench.plotMMPDFScoreF1(path_to_mmpdf_db, matching_type='matchingMSE', f1_type='f1Position')

# %% [markdown]
# #### F1 corrélation

# %%
workbench.plotMMPDFScoreF1(path_to_mmpdf_db, matching_type='matchingMSE', f1_type='f1Correlation')
